# %% [markdown]
# # Wavess Tech assignment

# %% [markdown]
# ## Task 1
#
# Goal: Build a small prototype that analyses Linkedin post performance and audience
# relevance.
#
# Deliverables:
#
# • Extract post features (text, hashtags, sentiment, etc.) and predict which posts perform best.
#
# • Analyse the post audience (roles, seniority, company type) and rank their relevance to a their ICP.
#
# • Provide both outputs in a clean, structured format (CSV or small dashboard).
#
# Tools: Python or R (you choose).
#
#
# Bonus: Suggest how this workflow could be automated or scaled.

# %%
# references
# https://www.b2brocket.ai/blog-posts/how-to-hone-your-icp-and-generate-more-leads-on-linkedin

# %%
# actor 1 : https://console.apify.com/actors/D51Mxn506e71aDPys/information/latest/readme
# actor 2 : https://console.apify.com/actors/J9UfswnR3Kae4O6vm/information/latest/readme
# actor 3 : https://console.apify.com/actors/WTiV7eppiChuBc8Xq/information/latest/readme
# actor 4 : https://console.apify.com/actors/2XnpwxfhSW1fAWElp/information/latest/readme

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from apify_client import ApifyClient

# Load environment variables from .env file
load_dotenv()
api_token = os.getenv("APIFY_API_TOKEN")

# Initialize the ApifyClient
client = ApifyClient(api_token)

# The LinkedIn post URL we are analyzing
linkedin_post_url = 'https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/'

# %%
print("Starting: Post Scraper")

# Actor and input configuration : "pratikdani/linkedin-posts-scraper"
post_scraper_actor_id = "D51Mxn506e71aDPys"

post_scraper_input = {
    "url": linkedin_post_url,
    "max_comments": 0 
}

# Run the actor and wait for it to finish
run = client.actor(post_scraper_actor_id).call(run_input=post_scraper_input)

# Fetch results from the actor's dataset
items = []
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    items.append(item)


with open('post_data.json', 'w', encoding='utf-8') as f:
    json.dump(items, f, ensure_ascii=False, indent=4)

print(f"Success: Saved {len(items)} post object(s) to post_data.json")

if items:
    print("\n--- Sample of first post data ---")
    print(json.dumps(items[0], indent=2))
# Out:
# Starting: Post Scraper
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> Status: RUNNING, Message:
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> 2025-11-12T13:11:36.492Z ACTOR: Pulling container image of build BIxJejEmBtxrvbg1J from registry.
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> 2025-11-12T13:11:40.132Z ACTOR: Creating container.
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> 2025-11-12T13:11:40.232Z ACTOR: Starting container.
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> 2025-11-12T13:11:41.575Z Actor is running on the Apify platform, `disable_browser_sandbox` was changed to True.
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> 2025-11-12T13:11:41.821Z [apify] INFO  Initializing Actor...
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> 2025-11-12T13:11:41.825Z [apify] INFO  System info ({"apify_sdk_version": "2.7.3", "apify_client_version": "1.12.2", "crawlee_version": "0.6.12", "python_version": "3.12.11", "os": "linux"})
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> 2025-11-12T13:11:43.175Z Job triggered successfully.
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> 2025-11-12T13:11:44.286Z Job still running... (attempt 1/30)
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> 2025-11-12T13:12:45.866Z Job completed successfully!
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> 2025-11-12T13:12:46.033Z [apify] INFO  Exiting Actor ({"exit_code": 0})
# [apify.linkedin-posts-scraper runId:Hudayw0duWsGrV2id] -> Status: SUCCEEDED, Message:
# Success: Saved 1 post object(s) to post_data.json
#
# --- Sample of first post data ---
# {
#   "account_type": "Organization",
#   "author_profile_pic": "https://media.licdn.com/dms/image/v2/D4E0BAQEKo8RSbFptLA/company-logo_100_100/company-logo_100_100/0/1706794863353/klarna_logo?e=2147483647&v=beta&t=ZmfQkR4vj3BEwNzTDEOzgsWswPNd4wpMYITYcTCkIL0",
#   "date_posted": "2025-07-04T12:26:36.965Z",
#   "document_cover_image": "https://media.licdn.com/dms/image/v2/D4D1FAQHG7VKVbr60DA/feedshare-document-cover-images_480/B4DZfVZuTtHMBU-/0/1751631988520?e=2147483647&v=beta&t=dBkxR6qTON_dN9f8jQMPQZWWEAWzDFgTXp1BVqleTQ0",
#   "document_page_count": 3,
#   "embedded_links": [
#     "https://lnkd.in/d3tFWFHJ"
#   ],
#   "external_link_data": null,
#   "hashtags": null,
#   "headline": "\ud83c\udf0d We\u2019re proud to announce the launch of our AI for Climate Resilience Program.",
#   "id": "7346877091532959746",
#   "images": [
#     "https://media.licdn.com/dms/image/v2/D4D1FAQHG7VKVbr60DA/feedshare-document-cover-images_480/B4DZfVZuTtHMBU-/0/1751631988520?e=2147483647&v=beta&t=dBkxR6qTON_dN9f8jQMPQZWWEAWzDFgTXp1BVqleTQ0",
#     "https://media.licdn.com/dms/image/v2/D4D1FAQHG7VKVbr60DA/feedshare-document-cover-images_480/B4DZfVZuTtHMBU-/1/1751631988520?e=2147483647&v=beta&t=LgPiWzD8u5FmWq_KbrfnxF9JUJua_7TTy6je22kunFw",
#     "https://media.licdn.com/dms/image/v2/D4D1FAQHG7VKVbr60DA/feedshare-document-cover-images_480/B4DZfVZuTtHMBU-/2/1751631988520?e=2147483647&v=beta&t=5kKn999qOx3Kzg4Yho2pgSLqUKKjhcizJwAcGPx0cNA"
#   ],
#   "input": {
#     "url": "https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/"
#   },
#   "more_articles_by_user": null,
#   "more_relevant_posts": [
#     {
#       "date_posted": "2025-10-22T13:11:43.719Z",
#       "embedded_links": [
#         "https://lnkd.in/d3tFWFHJ",
#         "https://ow.ly/SHiu50Xe6zG",
#         "https://ow.ly/EQyC30sQg7n",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/RmPc30sQeyb",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://www.linkedin.com/feed/hashtag/swiss",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/rTXo30sQey6",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://nl.linkedin.com/school/university-of-amsterdam/?trk=public_post-text",
#         "https://nl.linkedin.com/in/rianne-riemens-879761b3?trk=public_post-text",
#         "https://nl.linkedin.com/in/bjorn-beijnon?trk=public_post-text",
#         "https://lnkd.in/eRSNZQ4i"
#       ],
#       "hashtags": null,
#       "headline": null,
#       "images": null,
#       "num_comments": 0,
#       "num_likes": 39,
#       "post_id": "7386657600718774272",
#       "post_text": "Earlier this year, the glacier collapse in Blatten destroyed a village and reminded Switzerland how urgently we need to build climate resilience. At Swiss {ai} Weeks, Gr\u00e9goire Caro, Data Science Director at Swiss Re, explains why we turned this real-world event into our hackathon challenge: \u201cBuilding Resilience to Extreme Weather.\u201d Our goal was simple: inspire innovators to use AI for Resilience and develop ideas that could have a real impact on society\u2019s ability to adapt to climate risks. Learn more about AI at Swiss Re \ud83d\udd17 https://ow.ly/SHiu50Xe6zG",
#       "post_url": "https://www.linkedin.com/posts/swiss-re_earlier-this-year-the-glacier-collapse-in-activity-7386657600718774272-ReDN",
#       "use_url": "https://www.linkedin.com/posts/swiss-re_earlier-this-year-the-glacier-collapse-in-activity-7386657600718774272-ReDN",
#       "user_id": "swiss-re",
#       "videos": null
#     },
#     {
#       "date_posted": "2025-10-13T13:11:43.739Z",
#       "embedded_links": [
#         "https://lnkd.in/d3tFWFHJ",
#         "https://ow.ly/SHiu50Xe6zG",
#         "https://ow.ly/EQyC30sQg7n",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/RmPc30sQeyb",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://www.linkedin.com/feed/hashtag/swiss",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/rTXo30sQey6",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://nl.linkedin.com/school/university-of-amsterdam/?trk=public_post-text",
#         "https://nl.linkedin.com/in/rianne-riemens-879761b3?trk=public_post-text",
#         "https://nl.linkedin.com/in/bjorn-beijnon?trk=public_post-text",
#         "https://lnkd.in/eRSNZQ4i"
#       ],
#       "headline": null,
#       "images": null,
#       "num_comments": 0,
#       "num_likes": 4,
#       "post_id": "7381677259155255298",
#       "post_text": "From glacier collapses to heatwaves, climate risks are evolving fast. At Swiss {ai} Weeks, our team joined innovators across Switzerland to explore how AI can help societies stay resilient. Our challenge, \u201cBuilding Resilience to Extreme Weather,\u201d invited participants to design AI-powered early warning systems, faster insurance responses, and smarter data tools. Discover how Swiss Re is using tech and data to shape a more resilient future: \ud83d\udd17 https://ow.ly/EQyC30sQg7n #AIforResilience #Hackathon #TechForGood",
#       "post_url": "https://www.linkedin.com/posts/armando-zazueta-7175689_aiforresilience-hackathon-techforgood-activity-7381677259155255298-51Mk",
#       "use_url": "https://www.linkedin.com/posts/armando-zazueta-7175689_aiforresilience-hackathon-techforgood-activity-7381677259155255298-51Mk",
#       "user_id": "armando-zazueta-7175689",
#       "videos": null
#     },
#     {
#       "date_posted": "2025-10-13T13:11:43.753Z",
#       "embedded_links": [
#         "https://lnkd.in/d3tFWFHJ",
#         "https://ow.ly/SHiu50Xe6zG",
#         "https://ow.ly/EQyC30sQg7n",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/RmPc30sQeyb",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://www.linkedin.com/feed/hashtag/swiss",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/rTXo30sQey6",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://nl.linkedin.com/school/university-of-amsterdam/?trk=public_post-text",
#         "https://nl.linkedin.com/in/rianne-riemens-879761b3?trk=public_post-text",
#         "https://nl.linkedin.com/in/bjorn-beijnon?trk=public_post-text",
#         "https://lnkd.in/eRSNZQ4i"
#       ],
#       "headline": null,
#       "images": null,
#       "num_comments": 1,
#       "num_likes": 7,
#       "post_id": "7381249822454034432",
#       "post_text": "From glacier collapses to heatwaves, climate risks are evolving fast. At Swiss {ai} Weeks, our team joined innovators across Switzerland to explore how AI can help societies stay resilient. Our challenge, \u201cBuilding Resilience to Extreme Weather,\u201d invited participants to design AI-powered early warning systems, faster insurance responses, and smarter data tools. Discover how Swiss Re is using tech and data to shape a more resilient future: \ud83d\udd17 https://ow.ly/RmPc30sQeyb #AIforResilience #Hackathon #TechForGood",
#       "post_url": "https://www.linkedin.com/posts/panzergrenadier_aiforresilience-hackathon-techforgood-activity-7381249822454034432--U9f",
#       "use_url": "https://www.linkedin.com/posts/panzergrenadier_aiforresilience-hackathon-techforgood-activity-7381249822454034432--U9f",
#       "user_id": "panzergrenadier",
#       "videos": null
#     },
#     {
#       "date_posted": "2025-10-29T13:11:43.767Z",
#       "embedded_links": [
#         "https://lnkd.in/d3tFWFHJ",
#         "https://ow.ly/SHiu50Xe6zG",
#         "https://ow.ly/EQyC30sQg7n",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/RmPc30sQeyb",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://www.linkedin.com/feed/hashtag/swiss",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/rTXo30sQey6",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://nl.linkedin.com/school/university-of-amsterdam/?trk=public_post-text",
#         "https://nl.linkedin.com/in/rianne-riemens-879761b3?trk=public_post-text",
#         "https://nl.linkedin.com/in/bjorn-beijnon?trk=public_post-text",
#         "https://lnkd.in/eRSNZQ4i"
#       ],
#       "hashtags": null,
#       "headline": null,
#       "images": null,
#       "num_comments": 0,
#       "num_likes": 41,
#       "post_id": "7386804029697429505",
#       "post_text": "Earlier this month, we hosted our 8th Annual General Meeting, bringing together our LPs, portfolio company CEOs, and members of our Industrial Intelligence Network. We explored the macro landscape, AI\u2019s impact on industry, and the three megatrends shaping climate tech: The Power Crunch, AI for Industrial Efficiency, and AI Driving Disruptive Automation (we'll share our slides and thesis here in the coming weeks!) Grateful to our community for building the next generation of climate innovators with us!",
#       "post_url": "https://www.linkedin.com/posts/g2vp_earlier-this-month-we-hosted-our-8th-annual-activity-7386804029697429505-wfo9",
#       "use_url": "https://www.linkedin.com/posts/g2vp_earlier-this-month-we-hosted-our-8th-annual-activity-7386804029697429505-wfo9",
#       "user_id": "g2vp",
#       "videos": null
#     },
#     {
#       "date_posted": "2025-10-13T13:11:43.786Z",
#       "embedded_links": [
#         "https://lnkd.in/d3tFWFHJ",
#         "https://ow.ly/SHiu50Xe6zG",
#         "https://ow.ly/EQyC30sQg7n",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/RmPc30sQeyb",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://www.linkedin.com/feed/hashtag/swiss",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/rTXo30sQey6",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://nl.linkedin.com/school/university-of-amsterdam/?trk=public_post-text",
#         "https://nl.linkedin.com/in/rianne-riemens-879761b3?trk=public_post-text",
#         "https://nl.linkedin.com/in/bjorn-beijnon?trk=public_post-text",
#         "https://lnkd.in/eRSNZQ4i"
#       ],
#       "hashtags": null,
#       "headline": null,
#       "images": null,
#       "num_comments": 0,
#       "num_likes": 0,
#       "post_id": "7381572995779248128",
#       "post_text": "Can AI help save lives during a disaster? Students from ETH Z\u00fcrich answered that question for Swiss Re\u2019s hackathon challenge at Swiss {ai} Weeks \u2014 creating an AI-powered alert system that turns data into faster, smarter crisis response. \ud83e\udd16Hear about the hackathon from Swiss Re colleagues and discover what happens when innovation meets resilience.",
#       "post_url": "https://www.linkedin.com/posts/steve-paynter-4710abb_can-ai-help-save-lives-during-a-disaster-activity-7381572995779248128-f1s3",
#       "use_url": "https://www.linkedin.com/posts/steve-paynter-4710abb_can-ai-help-save-lives-during-a-disaster-activity-7381572995779248128-f1s3",
#       "user_id": "steve-paynter-4710abb",
#       "videos": null
#     },
#     {
#       "date_posted": "2025-10-13T13:11:43.798Z",
#       "embedded_links": [
#         "https://lnkd.in/d3tFWFHJ",
#         "https://ow.ly/SHiu50Xe6zG",
#         "https://ow.ly/EQyC30sQg7n",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/RmPc30sQeyb",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://www.linkedin.com/feed/hashtag/swiss",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/rTXo30sQey6",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://nl.linkedin.com/school/university-of-amsterdam/?trk=public_post-text",
#         "https://nl.linkedin.com/in/rianne-riemens-879761b3?trk=public_post-text",
#         "https://nl.linkedin.com/in/bjorn-beijnon?trk=public_post-text",
#         "https://lnkd.in/eRSNZQ4i"
#       ],
#       "hashtags": null,
#       "headline": null,
#       "images": null,
#       "num_comments": 0,
#       "num_likes": 63,
#       "post_id": "7381697979017207808",
#       "post_text": "Can AI help save lives during a disaster? Students from ETH Z\u00fcrich answered that question for Swiss Re\u2019s hackathon challenge at Swiss {ai} Weeks \u2014 creating an AI-powered alert system that turns data into faster, smarter crisis response. \ud83e\udd16Hear about the hackathon from Swiss Re colleagues and discover what happens when innovation meets resilience.",
#       "post_url": "https://www.linkedin.com/posts/ashok-shetty-b0a5b462_can-ai-help-save-lives-during-a-disaster-activity-7381697979017207808-Wn9w",
#       "use_url": "https://www.linkedin.com/posts/ashok-shetty-b0a5b462_can-ai-help-save-lives-during-a-disaster-activity-7381697979017207808-Wn9w",
#       "user_id": "ashok-shetty-b0a5b462",
#       "videos": null
#     },
#     {
#       "date_posted": "2025-10-13T13:11:43.820Z",
#       "embedded_links": [
#         "https://lnkd.in/d3tFWFHJ",
#         "https://ow.ly/SHiu50Xe6zG",
#         "https://ow.ly/EQyC30sQg7n",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/RmPc30sQeyb",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://www.linkedin.com/feed/hashtag/swiss",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/rTXo30sQey6",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://nl.linkedin.com/school/university-of-amsterdam/?trk=public_post-text",
#         "https://nl.linkedin.com/in/rianne-riemens-879761b3?trk=public_post-text",
#         "https://nl.linkedin.com/in/bjorn-beijnon?trk=public_post-text",
#         "https://lnkd.in/eRSNZQ4i"
#       ],
#       "hashtags": null,
#       "headline": null,
#       "images": null,
#       "num_comments": 1,
#       "num_likes": 28,
#       "post_id": "7381765427628249088",
#       "post_text": "Can AI help save lives during a disaster? Students from ETH Z\u00fcrich answered that question for Swiss Re\u2019s hackathon challenge at Swiss {ai} Weeks \u2014 creating an AI-powered alert system that turns data into faster, smarter crisis response. \ud83e\udd16Hear about the hackathon from Swiss Re colleagues and discover what happens when innovation meets resilience.",
#       "post_url": "https://www.linkedin.com/posts/armando-zazueta-7175689_can-ai-help-save-lives-during-a-disaster-activity-7381765427628249088-Vki_",
#       "use_url": "https://www.linkedin.com/posts/armando-zazueta-7175689_can-ai-help-save-lives-during-a-disaster-activity-7381765427628249088-Vki_",
#       "user_id": "armando-zazueta-7175689",
#       "videos": null
#     },
#     {
#       "date_posted": "2025-10-13T13:11:43.831Z",
#       "embedded_links": [
#         "https://lnkd.in/d3tFWFHJ",
#         "https://ow.ly/SHiu50Xe6zG",
#         "https://ow.ly/EQyC30sQg7n",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/RmPc30sQeyb",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://www.linkedin.com/feed/hashtag/swiss",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/rTXo30sQey6",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://nl.linkedin.com/school/university-of-amsterdam/?trk=public_post-text",
#         "https://nl.linkedin.com/in/rianne-riemens-879761b3?trk=public_post-text",
#         "https://nl.linkedin.com/in/bjorn-beijnon?trk=public_post-text",
#         "https://lnkd.in/eRSNZQ4i"
#       ],
#       "hashtags": null,
#       "headline": null,
#       "images": null,
#       "num_comments": 1,
#       "num_likes": 23,
#       "post_id": "7383330644434595840",
#       "post_text": "Can AI help save lives during a disaster? Students from ETH Z\u00fcrich answered that question for Swiss Re\u2019s hackathon challenge at Swiss {ai} Weeks \u2014 creating an AI-powered alert system that turns data into faster, smarter crisis response. \ud83e\udd16Hear about the hackathon from Swiss Re colleagues and discover what happens when innovation meets resilience.",
#       "post_url": "https://www.linkedin.com/posts/pavelh2_can-ai-help-save-lives-during-a-disaster-activity-7383330644434595840-yNtp",
#       "use_url": "https://www.linkedin.com/posts/pavelh2_can-ai-help-save-lives-during-a-disaster-activity-7383330644434595840-yNtp",
#       "user_id": "pavelh2",
#       "videos": null
#     },
#     {
#       "date_posted": "2025-10-13T13:11:43.841Z",
#       "embedded_links": [
#         "https://lnkd.in/d3tFWFHJ",
#         "https://ow.ly/SHiu50Xe6zG",
#         "https://ow.ly/EQyC30sQg7n",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/RmPc30sQeyb",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://www.linkedin.com/feed/hashtag/swiss",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/rTXo30sQey6",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://nl.linkedin.com/school/university-of-amsterdam/?trk=public_post-text",
#         "https://nl.linkedin.com/in/rianne-riemens-879761b3?trk=public_post-text",
#         "https://nl.linkedin.com/in/bjorn-beijnon?trk=public_post-text",
#         "https://lnkd.in/eRSNZQ4i"
#       ],
#       "headline": null,
#       "images": null,
#       "num_comments": 0,
#       "num_likes": 13,
#       "post_id": "7381248777946529792",
#       "post_text": "From glacier collapses to heatwaves, climate risks are evolving fast. At #Swiss {ai} Weeks, our team joined innovators across Switzerland to explore how AI can help societies stay resilient. Our challenge, \u201cBuilding Resilience to Extreme Weather,\u201d invited participants to design AI-powered early warning systems, faster insurance responses, and smarter data tools. Discover how Swiss Re is using tech and data to shape a more resilient future: \ud83d\udd17 https://ow.ly/rTXo30sQey6 #AIforResilience #Hackathon #TechForGood",
#       "post_url": "https://www.linkedin.com/posts/cgkbansal_swiss-aiforresilience-hackathon-activity-7381248777946529792-_dG7",
#       "use_url": "https://www.linkedin.com/posts/cgkbansal_swiss-aiforresilience-hackathon-activity-7381248777946529792-_dG7",
#       "user_id": "cgkbansal",
#       "videos": null
#     },
#     {
#       "date_posted": "2025-10-29T13:11:43.861Z",
#       "embedded_links": [
#         "https://lnkd.in/d3tFWFHJ",
#         "https://ow.ly/SHiu50Xe6zG",
#         "https://ow.ly/EQyC30sQg7n",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/RmPc30sQeyb",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://www.linkedin.com/feed/hashtag/swiss",
#         "https://ch.linkedin.com/company/swiss-re?trk=public_post-text",
#         "https://ow.ly/rTXo30sQey6",
#         "https://www.linkedin.com/feed/hashtag/aiforresilience",
#         "https://www.linkedin.com/feed/hashtag/hackathon",
#         "https://www.linkedin.com/feed/hashtag/techforgood",
#         "https://nl.linkedin.com/school/university-of-amsterdam/?trk=public_post-text",
#         "https://nl.linkedin.com/in/rianne-riemens-879761b3?trk=public_post-text",
#         "https://nl.linkedin.com/in/bjorn-beijnon?trk=public_post-text",
#         "https://lnkd.in/eRSNZQ4i"
#       ],
#       "hashtags": null,
#       "headline": null,
#       "images": [
#         "https://media.licdn.com/dms/image/v2/D4E22AQF4kpAesLII7g/feedshare-shrink_800/B4EZoa24H4KcAg-/0/1761387186061?e=2147483647&v=beta&t=RWJbrluxzw_xRUXQH70rEMn5txluMOApcdWqXJpln-k"
#       ],
#       "num_comments": 0,
#       "num_likes": 2,
#       "post_id": "7387793324377792512",
#       "post_text": "Who formats our futures? Big tech, green myths, and data politics. Everyday life increasingly runs through the ecosystems of Big Tech. AI and digital platforms are not neutral technologies. They shape the climate crisis, our identities, and even our political imagination. At the event 'Who Formats Our Futures?', organized by the University of Amsterdam , Rianne Riemens and Bjorn Beijnon exposed two sides of platform power: its environmental footprint and its social consequences. In a three-part short series, we unravel their messages. This is part 1: https://lnkd.in/eRSNZQ4i",
#       "post_url": "https://www.linkedin.com/posts/ioplusen_who-formats-our-futures-big-tech-green-activity-7387793324377792512-o1bD",
#       "use_url": "https://www.linkedin.com/posts/ioplusen_who-formats-our-futures-big-tech-green-activity-7387793324377792512-o1bD",
#       "user_id": "ioplusen",
#       "videos": null
#     }
#   ],
#   "num_comments": 7,
#   "num_connections": null,
#   "num_likes": 98,
#   "post_text": "\ud83c\udf0d We\u2019re proud to announce the launch of our AI for Climate Resilience Program. AI already powers everything we do at Klarna \u2014 and now we\u2019re turning that same expertise toward the front lines of climate change. We take pride in our legacy as a climate leader, and we\u2019re committed to driving positive change for the future. The AI for Climate Resilience Program will support pioneering projects that harness artificial intelligence to help climate-vulnerable communities adapt and thrive. This is technology in service of both people and the planet. This program will support local, practical, and community-owned solutions. From strengthening food security and improving health systems to building coastal resilience in the face of climate change. What\u2019s on offer: \ud83d\udcb8 Grants of up to $300,000 \ud83e\uddd1\ud83c\udf93 Mentorship, training, and a supportive community of practice We encourage applications from organizations working to reduce vulnerability of local communities to climate-related risks in low- and middle-income countries. We welcome early stage applications as well, from teams that need support in developing technical details further. Whether you\u2019re using AI to support smallholder farmers, build early warning systems, or translate complex risk data into community action plans, we want to hear from you! Find out more about the program and apply here \ud83d\udc49 https://lnkd.in/d3tFWFHJ",
#   "post_text_html": "&#x1F30D; We&#x2019;re proud to announce the launch of our AI for Climate Resilience Program.<br/><br/>AI already powers everything we do at Klarna &#x2014; and now we&#x2019;re turning that same expertise toward the front lines of climate change. We take pride in our legacy as a climate leader, and we&#x2019;re committed to driving positive change for the future. The AI for Climate Resilience Program will support pioneering projects that harness artificial intelligence to help climate-vulnerable communities adapt and thrive.<br/><br/>This is technology in service of both people and the planet.<br/><br/>This program will support local, practical, and community-owned solutions. From strengthening food security and improving health systems to building coastal resilience in the face of climate change.<br/><br/>What&#x2019;s on offer:<br/>&#x1F4B8; Grants of up to $300,000<br/>&#x1F9D1;&#x1F393; Mentorship, training, and a supportive community of practice<br/><br/>We encourage applications from organizations working to reduce vulnerability of local communities to climate-related risks in low- and middle-income countries. We welcome early stage applications as well, from teams that need support in developing technical details further. Whether you&#x2019;re using AI to support smallholder farmers, build early warning systems, or translate complex risk data into community action plans, we want to hear from you!<br/><br/>Find out more about the program and apply here &#x1F449; <a class=\"link\" href=\"https://www.linkedin.com/redir/redirect?url=https%3A%2F%2Flnkd%2Ein%2Fd3tFWFHJ&amp;urlhash=RZFd&amp;trk=public_post-text\" target=\"_self\" rel=\"nofollow\" data-tracking-control-name=\"public_post-text\" data-tracking-will-navigate>https://lnkd.in/d3tFWFHJ</a>",
#   "post_type": "post",
#   "repost": {
#     "repost_attachments": null,
#     "repost_hangtags": null,
#     "tagged_companies": null,
#     "tagged_users": null
#   },
#   "tagged_companies": [],
#   "tagged_people": [],
#   "timestamp": "2025-11-12T13:11:43.951Z",
#   "title": "Klarna's Climate Resilience Program | Klarna",
#   "top_visible_comments": [
#     {
#       "comment": "Proud to be part of this important initiative and very excited to see how AI can support climate resilience in communities that are most affected.",
#       "comment_date": "2025-07-15T13:11:43.866Z",
#       "comment_images": null,
#       "num_reactions": 5,
#       "tagged_users": null,
#       "use_url": "https://es.linkedin.com/in/salah-said?trk=public_post_comment_actor-name",
#       "user_id": "salah-said",
#       "user_name": "Salah Said",
#       "user_title": "Sustainability I ESG I Corporate Responsibility at Klarna I ex-Zalando | Social Innovation & Entrepreneurship | Design Thinking | BMI | LSP | Sustainable Fashion / Finance / E-commerce | Carbon Removal"
#     },
#     {
#       "comment": "Extraordinary cool! Salah Said , Petter William Sundelin , Nina Siemiatkowski and all involved!",
#       "comment_date": "2025-07-15T13:11:43.868Z",
#       "comment_images": null,
#       "num_reactions": 3,
#       "tagged_users": [
#         "https://es.linkedin.com/in/salah-said?trk=public_post_comment-text",
#         "https://se.linkedin.com/in/petter-william-sundelin?trk=public_post_comment-text"
#       ],
#       "use_url": "https://se.linkedin.com/in/katarinabjork?trk=public_post_comment_actor-name",
#       "user_id": "katarinabjork",
#       "user_name": "Katarina Wangler Bj\u00f6rk",
#       "user_title": "IMAGINE Leader | Climate, Sustain Tech & Policy | Sustainable Business Innovation Transformation & Finance | Ex-EY | MBA"
#     },
#     {
#       "comment": "Glad to be part of this initiative\u2014putting AI to work for climate resilience where it matters most \ud83d\ude4c",
#       "comment_date": "2025-07-15T13:11:43.870Z",
#       "comment_images": null,
#       "num_reactions": 5,
#       "tagged_users": null,
#       "use_url": "https://se.linkedin.com/in/petter-william-sundelin?trk=public_post_comment_actor-name",
#       "user_id": "petter-william-sundelin",
#       "user_name": "Petter William Sundelin",
#       "user_title": "Senior Product Marketing Manager p\u00e5 Klarna"
#     },
#     {
#       "comment": "Klarna Well dang, talk about an awesome opportunity! Time to save this and see if I can apply. \ud83d\ude0e\ud83e\udd14",
#       "comment_date": "2025-07-15T13:11:43.871Z",
#       "comment_images": null,
#       "num_reactions": 0,
#       "tagged_users": null,
#       "use_url": "https://www.linkedin.com/in/nathaniel-burola-5763ab49?trk=public_post_comment_actor-name",
#       "user_id": "nathaniel-burola-5763ab49",
#       "user_name": "Nathaniel Burola",
#       "user_title": "AI & Environment Research Consultant | Master of Tech Policy (MTP) Student at the RAND School of Public Policy | Fellow at The Digital Economist"
#     },
#     {
#       "comment": "Fantastic team Klarna !",
#       "comment_date": "2025-07-15T13:11:43.871Z",
#       "comment_images": null,
#       "num_reactions": 0,
#       "tagged_users": null,
#       "use_url": "https://www.linkedin.com/company/borderlesscx?trk=public_post_comment_actor-name",
#       "user_id": "borderlesscx",
#       "user_name": "BorderlessCX\u2122",
#       "user_title": null
#     },
#     {
#       "comment": "Well done! You make lives of people so much easier and prettier! :) AI will definitely ease things even more!",
#       "comment_date": "2025-07-15T13:11:43.872Z",
#       "comment_images": null,
#       "num_reactions": 0,
#       "tagged_users": null,
#       "use_url": "https://pt.linkedin.com/in/natalja-%C4%BCefonova-7b255a46?trk=public_post_comment_actor-name",
#       "user_id": "natalja-%C4%BCefonova-7b255a46",
#       "user_name": "Natalja \u013befonova",
#       "user_title": "Global service provider with expertise in Networking, SASE, Cloud & Web Security, CDN, Hosting and outstaffing."
#     },
#     {
#       "comment": "Super interesting team Klarna \u267b\ufe0f \ud83d\udc9a \ud83c\udfd7\ufe0f",
#       "comment_date": "2025-07-15T13:11:43.875Z",
#       "comment_images": null,
#       "num_reactions": 1,
#       "tagged_users": null,
#       "use_url": "https://se.linkedin.com/company/plantmore?trk=public_post_comment_actor-name",
#       "user_id": "plantmore",
#       "user_name": "Plantmore.com - for the climate",
#       "user_title": null
#     }
#   ],
#   "url": "https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v",
#   "use_url": "https://se.linkedin.com/company/klarna?trk=public_post_feed-actor-image",
#   "user_articles": 0,
#   "user_followers": 384272,
#   "user_id": "klarna",
#   "user_posts": 0,
#   "user_title": null,
#   "video_duration": null,
#   "video_thumbnail": null,
#   "videos": null
# }

# %%
print("Starting: Post Reactions Scraper")

# Actor and input configuration : "apimaestro/linkedin-post-reactions"
reactions_scraper_actor_id = "J9UfswnR3Kae4O6vm"
reactions_scraper_input = {
    "post_urls": [linkedin_post_url],
    "reaction_type": "ALL"
}

# Run the actor and wait for it to finish
run = client.actor(reactions_scraper_actor_id).call(run_input=reactions_scraper_input)

# Fetch results from the actor's dataset
items = []
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    items.append(item)

# Save the raw list of dictionaries to a JSON file
with open('post_reactions.json', 'w', encoding='utf-8') as f:
    json.dump(items, f, ensure_ascii=False, indent=4)

print(f"Success: Saved {len(items)} reactions to post_reactions.json")

# Print the first item to verify
if items:
    print("\n--- Sample of first reaction data ---")
    print(json.dumps(items[0], indent=2))
# Out:
# Starting: Post Reactions Scraper
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> Status: RUNNING, Message:
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:17.362Z ACTOR: Pulling container image of build 1JUeXg5YbqPyJOZYv from registry.
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:17.364Z ACTOR: Creating container.
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:17.427Z ACTOR: Starting container.
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.482Z INFO  System info {"apifyVersion":"3.5.0","apifyClientVersion":"2.17.0","crawleeVersion":"3.15.1","osType":"Linux","nodeVersion":"v20.19.5"}
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.671Z Input received: {
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.672Z   "post_urls": [
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.673Z     "https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/"
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.675Z   ],
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.677Z   "reaction_type": "ALL",
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.677Z   "page_number": 1,
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.679Z   "limit": 100
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.680Z }
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.920Z Processing 1 post(s)...
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.927Z Manual pagination mode: fetching page 1 only
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.928Z Result limit per post: 100
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.929Z Reaction type filter: ALL
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.930Z
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.931Z ----- Processing batch 1 of 1 (1 posts) -----
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.931Z
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.932Z Starting to fetch reactions for post https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/...
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:18.933Z Fetching reactions for post https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/ - Page 1 (attempt 1/2)...
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:20.987Z Retrieved 98 reactions from page 1
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:20.989Z Manual pagination mode: fetched page 1, stopping
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:20.990Z Successfully fetched 98 reactions for post https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:20.990Z
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:20.991Z ===== POST: https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/ =====
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:20.992Z Status: Success
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:20.993Z Total reactions extracted: 98 out of 98
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:20.994Z ===== END https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/ =====
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:21.038Z Saved batch 1 of 1 (98 reactions)
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:21.039Z
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:21.040Z
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:21.041Z ========== BATCH PROCESSING SUMMARY ==========
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:21.042Z Total posts processed: 1
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:21.043Z Successfully processed: 1
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:21.046Z Failed to process: 0
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:21.047Z Total reactions extracted: 98
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> 2025-11-12T13:20:21.048Z ==============================================
# [apify.linkedin-post-reactions runId:U94EQjMOB0r8Y72zh] -> Status: SUCCEEDED, Message:
# Success: Saved 98 reactions to post_reactions.json
#
# --- Sample of first reaction data ---
# {
#   "reaction_type": "LIKE",
#   "reactor": {
#     "urn": "ACoAADzUcLcBZm6Fm3KykTDh-WWMcGkEJUXqC90",
#     "name": "Sagar Mattikere Anand",
#     "headline": "AI/ML Engineer & Backend Developer | RAG Systems | Python, Django, Docker | Turning Data Challenges into Scalable Solutions",
#     "profile_url": "https://www.linkedin.com/in/ACoAADzUcLcBZm6Fm3KykTDh-WWMcGkEJUXqC90",
#     "profile_pictures": {
#       "small": "https://media.licdn.com/dms/image/v2/D5635AQEZ-0M5BiL9zw/profile-framedphoto-shrink_100_100/B56Zm4767dHAAk-/0/1759744340075?e=1763560800&v=beta&t=5vD8SODL_efjb1EyzWB2PhPVcCdnUopLzrsdqtl42wY",
#       "medium": "https://media.licdn.com/dms/image/v2/D5635AQEZ-0M5BiL9zw/profile-framedphoto-shrink_200_200/B56Zm4767dHAAY-/0/1759744340075?e=1763560800&v=beta&t=8LjgT-oSD47kVcBPdZ5s-CfgQvQBalQdH0dTY19e8X4",
#       "large": "https://media.licdn.com/dms/image/v2/D5635AQEZ-0M5BiL9zw/profile-framedphoto-shrink_400_400/B56Zm4767dHAAc-/0/1759744340056?e=1763560800&v=beta&t=EwxJjcSmx09oz7-2USq12RadB3SGGL0UQ76EvachCks",
#       "original": "https://media.licdn.com/dms/image/v2/D5635AQEZ-0M5BiL9zw/profile-framedphoto-shrink_800_800/B56Zm4767dHAAg-/0/1759744340075?e=1763560800&v=beta&t=0kD6YoHCzOslEHKOsksSFvpkTAtsBYn6aQ_0Dh9-FEU"
#     }
#   },
#   "_metadata": {
#     "post_url": "https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/",
#     "page_number": 1,
#     "total_reactions": 98,
#     "reaction_type_filter": "ALL"
#   }
# }

# %%
print("Starting: Post Reshares Scraper")

# Actor and input configuration
reshares_scraper_actor_id = "apimaestro/linkedin-post-reshares"
reshares_scraper_input = {
    "post_urls": [linkedin_post_url]}

# Run the actor and wait for it to finish
run = client.actor(reshares_scraper_actor_id).call(run_input=reshares_scraper_input)

# Fetch results from the actor's dataset
items = []
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    items.append(item)

# Save the raw list of dictionaries to a JSON file
with open('post_reshares.json', 'w', encoding='utf-8') as f:
    json.dump(items, f, ensure_ascii=False, indent=4)

print(f"Success: Saved {len(items)} reshares to post_reshares.json")

# Print the first item to verify
if items:
    print("\n--- Sample of first reshare data ---")
    print(json.dumps(items[0], indent=2))
# Out:
# Starting: Post Reshares Scraper
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> Status: RUNNING, Message:
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:38.780Z ACTOR: Pulling container image of build b7UoQhPpVVTv3xzVo from registry.
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:38.782Z ACTOR: Creating container.
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:42.070Z ACTOR: Starting container.
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.229Z INFO  System info {"apifyVersion":"3.5.0","apifyClientVersion":"2.17.0","crawleeVersion":"3.15.1","osType":"Linux","nodeVersion":"v20.19.5"}
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.374Z Input received: {
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.376Z   "post_urls": [
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.378Z     "https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/"
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.380Z   ],
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.382Z   "page_number": 1,
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.389Z   "limit": 100
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.391Z }
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.420Z Processing 1 post(s)...
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.422Z Page number: 1
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.424Z Result limit per post: 100
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.426Z
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.428Z ----- Processing batch 1 of 1 (1 posts) -----
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.430Z
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.433Z Starting to fetch reposts for post https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/...
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:43.435Z Fetching reposts for post https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/ - Page 1 (attempt 1/2)...
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.830Z Retrieved 15 reposts from page 1
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.838Z
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.840Z ===== POST: https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/ =====
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.842Z Status: Success
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.844Z Reposts extracted: 15 out of 15 total
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.846Z ===== END https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/ =====
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.869Z Saved batch 1 of 1 (15 reposts)
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.871Z
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.873Z
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.876Z ========== BATCH PROCESSING SUMMARY ==========
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.878Z Total posts processed: 1
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.879Z Successfully processed: 1
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.881Z Failed to process: 0
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.883Z Total reposts extracted: 15
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.885Z Page number: 1
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> 2025-11-12T13:24:45.887Z ==============================================
# [apify.linkedin-post-reshares runId:IchCCn1UXJ9GUqCAi] -> Status: SUCCEEDED, Message:
# Success: Saved 15 reshares to post_reshares.json
#
# --- Sample of first reshare data ---
# {
#   "id": "7359525268497100800",
#   "url": "https://www.linkedin.com/feed/update/urn:li:activity:7359525268497100800",
#   "reposter": {
#     "urn": "",
#     "name": "Momentswithbren",
#     "profile_url": "https://www.linkedin.com/company/momentswithbren/?miniCompanyUrn=urn%3Ali%3Afsd_company%3A29290478",
#     "profile_pictures": {
#       "small": "",
#       "medium": "",
#       "large": "",
#       "original": ""
#     },
#     "is_premium": false
#   },
#   "reshared_post": {
#     "id": "7346877089213571072",
#     "url": "https://www.linkedin.com/feed/update/urn:li:ugcPost:7346877089213571072",
#     "text": "\ud83c\udf0d We\u2019re proud to announce the launch of our AI for Climate Resilience Program.\n\nAI already powers everything we do at Klarna \u2014 and now we\u2019re turning that same expertise toward the front lines of climate change. We take pride in our legacy as a climate leader, and we\u2019re committed to driving positive change for the future. The AI for Climate Resilience Program will support pioneering projects that harness artificial intelligence to help climate-vulnerable communities adapt and thrive.\n\nThis is technology in service of both people and the planet.\n\nThis program will support local, practical, and community-owned solutions. From strengthening food security and improving health systems to building coastal resilience in the face of climate change.\n\nWhat\u2019s on offer:\n\ud83d\udcb8 Grants of up to $300,000\n\ud83e\uddd1\u200d\ud83c\udf93 Mentorship, training, and a supportive community of practice\n\nWe encourage applications from organizations working to reduce vulnerability of local communities to climate-related risks in low- and middle-income countries. We welcome early stage applications as well, from teams that need support in developing technical details further. Whether you\u2019re using AI to support smallholder farmers, build early warning systems, or translate complex risk data into community action plans, we want to hear from you!\n\nFind out more about the program and apply here \ud83d\udc49 https://lnkd.in/d3tFWFHJ",
#     "author": {
#       "name": "Klarna",
#       "urn": "",
#       "headline": "384,274 followers",
#       "profile_url": "https://www.linkedin.com/company/klarna/posts",
#       "profile_picture": ""
#     },
#     "type": {
#       "format": "document",
#       "audience": "public",
#       "categories": []
#     },
#     "media": [
#       {
#         "type": "document",
#         "title": "",
#         "description": "",
#         "url": ""
#       }
#     ]
#   },
#   "stats": {
#     "reactions": {
#       "total": 0,
#       "likes": 0,
#       "comments": 0,
#       "shares": 0,
#       "details": []
#     }
#   },
#   "visibility": "PUBLIC",
#   "repost_type": "RESHARE_ANALYTICS_FEED",
#   "timestamp": {
#     "timestamp": 1754647557377,
#     "date": "2025-08-08 12:05:57",
#     "relative": "4mo"
#   },
#   "_metadata": {
#     "post_url": "https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/",
#     "page_number": 1,
#     "total_reposts": 15
#   }
# }

# %%
print("Starting: Post Comments Scraper")

# Actor and input configuration
comments_scraper_actor_id = "apimaestro/linkedin-post-comments-replies-engagements-scraper-no-cookies"
comments_scraper_input = {
    "postIds": [linkedin_post_url],
    "sortOrder": "most recent"
}

# Run the actor and wait for it to finish
run = client.actor(comments_scraper_actor_id).call(run_input=comments_scraper_input)

# Fetch results from the actor's dataset
items = []
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    items.append(item)

# Save the raw list of dictionaries to a JSON file
with open('post_comments.json', 'w', encoding='utf-8') as f:
    json.dump(items, f, ensure_ascii=False, indent=4)

print(f"Success: Saved {len(items)} comments to post_comments.json")

# Print the first item to verify
if items:
    print("\n--- Sample of first comment data ---")
    print(json.dumps(items[0], indent=2))
# Out:
# Starting: Post Comments Scraper
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> Status: RUNNING, Message:
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:21.542Z ACTOR: Pulling container image of build 0ZMsbFMCNcaTZrVc9 from registry.
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:21.545Z ACTOR: Creating container.
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:21.713Z ACTOR: Starting container.
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.688Z INFO  System info {"apifyVersion":"3.5.0","apifyClientVersion":"2.17.0","crawleeVersion":"3.15.1","osType":"Linux","nodeVersion":"v20.19.5"}
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.881Z Input received: {
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.889Z   "postIds": [
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.891Z     "https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/"
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.892Z   ],
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.894Z   "sortOrder": "most recent",
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.896Z   "page_number": 1,
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.898Z   "limit": 100
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.905Z }
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.933Z Sort order: most recent
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.946Z Page number: 1
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.948Z Processing 1 post(s)...
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.950Z Result limit per post: 100
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.952Z
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:22.954Z ----- Processing batch 1 of 1 (1 posts) -----
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.695Z
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.697Z ===== POST: https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/ =====
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.699Z Response status: 200
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.701Z Status: Success
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.703Z Comments processed: 7
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.704Z Total post comments: 7
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.848Z Pushed 7 comments to dataset
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.850Z ===== END https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/ =====
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.888Z
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.890Z
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.892Z ========== BATCH PROCESSING SUMMARY ==========
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.893Z Total posts processed: 1
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.895Z Successfully processed: 1
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.896Z Failed to process: 0
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.898Z Comments extracted: 7
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.899Z Total post comments: 7
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.901Z Page number: 1
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> 2025-11-12T13:27:24.902Z ==============================================
# [apify.linkedin-post-comments-replies-engagements-scraper-no-cookies runId:XGRZbTfqKUzoduaXD] -> Status: SUCCEEDED, Message:
# Success: Saved 8 comments to post_comments.json
#
# --- Sample of first comment data ---
# {
#   "comment_id": "7350462303886049280",
#   "text": "Well done! You make lives of people so much easier and prettier! :) AI will definitely ease things even more!",
#   "posted_at": {
#     "timestamp": 1752486778232,
#     "date": "2025-07-14 11:52:58",
#     "relative": "17w"
#   },
#   "is_edited": false,
#   "is_pinned": false,
#   "comment_url": "https://www.linkedin.com/feed/update/urn:li:ugcPost:7346877089213571072?commentUrn=urn%3Ali%3Acomment%3A%28ugcPost%3A7346877089213571072%2C7350462303886049280%29&dashCommentUrn=urn%3Ali%3Afsd_comment%3A%287350462303886049280%2Curn%3Ali%3AugcPost%3A7346877089213571072%29",
#   "author": {
#     "name": "Natalja \u013befonova",
#     "headline": "Global service provider with expertise in Networking, SASE, Cloud & Web Security, CDN, Hosting and outstaffing.",
#     "profile_url": "https://www.linkedin.com/in/natalja-%C4%BCefonova-7b255a46",
#     "profile_picture": "https://media.licdn.com/dms/image/v2/C5603AQHrn8tHsh5Xzg/profile-displayphoto-shrink_800_800/profile-displayphoto-shrink_800_800/0/1517432717652?e=1764806400&v=beta&t=nhmkhw1ZRmWZkZVzavU_xodugUex5BecmAHzr315HAs"
#   },
#   "stats": {
#     "total_reactions": 0,
#     "reactions": {
#       "like": 0,
#       "appreciation": 0,
#       "empathy": 0,
#       "interest": 0,
#       "praise": 0
#     },
#     "comments": 0
#   },
#   "replies": [],
#   "post_input": "https://www.linkedin.com/posts/klarna_klarnas-climate-resilience-program-activity-7346877091532959746-748v/",
#   "totalComments": 7
# }

# %% [markdown]
# ## data cleaning

# %%
import pandas as pd
import json

def load_json_file(filename):
    """Safely loads a JSON file into a list of dictionaries."""
    try:
        with open(filename, 'r', encoding='utf-8') as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        print(f"Warning: Could not load or parse {filename}. Returning empty list.")
        return []

# Load the raw data from each file
post_data_raw = load_json_file('post_data.json')
reactions_raw = load_json_file('post_reactions.json')
reshares_raw = load_json_file('post_reshares.json')
comments_raw = load_json_file('post_comments.json')

print(f"Loaded {len(post_data_raw)} post records.")
print(f"Loaded {len(reactions_raw)} reaction records.")
print(f"Loaded {len(reshares_raw)} reshare records.")
print(f"Loaded {len(comments_raw)} comment records.")
# Out:
# Loaded 1 post records.
# Loaded 98 reaction records.
# Loaded 15 reshare records.
# Loaded 8 comment records.

# %%
import pandas as pd
import re

def clean_post_data(post_data_list):
    """Cleans and transforms the raw post data from the Apify actor."""
    if not post_data_list:
        print("No post data to process.")
        return pd.DataFrame()

    # We are only processing the first post from the list
    post = post_data_list[0]

    # Extract hashtags from post_text if the hashtags field is null
    hashtags = post.get('hashtags')
    if not hashtags:
        text = post.get('post_text', '')
        hashtags = re.findall(r"#(\w+)", text)

    # Prepare the cleaned data in a dictionary
    cleaned_post = {
        'post_id': post.get('id'),
        'post_url': post.get('url'),
        'post_text': post.get('post_text', '').strip(),
        'posted_at': pd.to_datetime(post.get('date_posted')),
        'author_name': post.get('user_id'), # Using user_id as it represents the author's handle
        'author_url': post.get('use_url'),  # use_url links to the author's page
        'likes_count': post.get('num_likes', 0),
        'comments_count': post.get('num_comments', 0),
        'shares_count': post.get('shares_count', 0), # Field not present, defaulting to 0
        'hashtags': hashtags,
        'media_urls': post.get('images', []) # 'images' field contains the list of media URLs
    }
    
    # Create a DataFrame from the single dictionary
    df = pd.DataFrame([cleaned_post])
    return df

# --- Execution ---
post_df = clean_post_data(post_data_raw)

print("Cleaned Post DataFrame:")
print(post_df.info())
print("\n")
# Display the full post text for verification
pd.set_option('display.max_colwidth', None)
display(post_df[['post_id', 'author_name', 'likes_count', 'comments_count', 'post_text']])
# Out:
# Cleaned Post DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   post_id         1 non-null      object
#  1   post_url        1 non-null      object
#  2   post_text       1 non-null      object
#  3   posted_at       1 non-null      datetime64[ns, UTC]
#  4   author_name     1 non-null      object
#  5   author_url      1 non-null      object
#  6   likes_count     1 non-null      int64
#  7   comments_count  1 non-null      int64
#  8   shares_count    1 non-null      int64
#  9   hashtags        1 non-null      object
#  10  media_urls      1 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(3), object(7)
# memory usage: 220.0+ bytes
# None
#                post_id author_name  likes_count  comments_count  \
# 0  7346877091532959746      klarna           98               7
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         post_text
# 0  🌍 We’re proud to announce the launch of our AI for Climate Resilience Program. AI already powers everything we do at Klarna — and now we’re turning that same expertise toward the front lines of climate change. We take pride in our legacy as a climate leader, and we’re committed to driving positive change for the future. The AI for Climate Resilience Program will support pioneering projects that harness artificial intelligence to help climate-vulnerable communities adapt and thrive. This is technology in service of both people and the planet. This program will support local, practical, and community-owned solutions. From strengthening food security and improving health systems to building coastal resilience in the face of climate change. What’s on offer: 💸 Grants of up to $300,000 🧑🎓 Mentorship, training, and a supportive community of practice We encourage applications from organizations working to reduce vulnerability of local communities to climate-related risks in low- and middle-income countries. We welcome early stage applications as well, from teams that need support in developing technical details further. Whether you’re using AI to support smallholder farmers, build early warning systems, or translate complex risk data into community action plans, we want to hear from you! Find out more about the program and apply here 👉 https://lnkd.in/d3tFWFHJ

# %%
import pandas as pd
import numpy as np
import re

def clean_and_finalize_audience(reactions_list, reshares_list, comments_list):
    """
    FINAL CORRECTED VERSION: Cleans, normalizes, and consolidates all audience data,
    grouping by a normalized name to ensure true uniqueness and prevent duplicates.
    """
    all_engagements = []

    # 1. Process and combine all sources into a single standardized list
    # Ensure that a name and profile_url exist before adding to the list
    for item in reactions_list:
        actor = item.get('reactor', {})
        if actor and actor.get('profile_url') and actor.get('name'):
            all_engagements.append({
                'profile_url': actor['profile_url'],
                'name': actor['name'],
                'headline': actor.get('headline'),
                'engagement_type': 'reaction'
            })
    for item in reshares_list:
        actor = item.get('reposter', {})
        if actor and actor.get('profile_url') and actor.get('name'):
            all_engagements.append({
                'profile_url': actor['profile_url'],
                'name': actor['name'],
                'headline': actor.get('headline'),
                'engagement_type': 'reshare'
            })
    for item in comments_list:
        if 'comment_id' not in item: continue # Skip summary object
        actor = item.get('author', {})
        if actor and actor.get('profile_url') and actor.get('name'):
            all_engagements.append({
                'profile_url': actor['profile_url'],
                'name': actor['name'],
                'headline': actor.get('headline'),
                'engagement_type': 'comment',
                'comment_text': item.get('text', '').strip()
            })

    if not all_engagements:
        print("No audience data to process.")
        return pd.DataFrame()

    # 2. Create a DataFrame and drop any rows that are missing a name
    df = pd.DataFrame(all_engagements).dropna(subset=['name'])

    # 3. **CRITICAL STEP: Normalize the 'name' column to use as a reliable key**
    df['normalized_name'] = df['name'].str.lower().str.strip()

    # 4. One-hot encode engagement types
    df = pd.get_dummies(df, columns=['engagement_type'], prefix='', prefix_sep='').rename(
        columns={'reaction': 'reacted', 'comment': 'commented', 'reshare': 'reshared'}
    )
    
    # 5. Group by the new 'normalized_name' and aggregate the data
    aggregation_rules = {
        'name': 'first',        # Keep one of the original capitalized names
        'profile_url': 'first', # Keep one of the URLs for reference
        'headline': 'first',    # Keep the first headline found
        'reacted': 'max',       # Consolidate one-hot columns
        'commented': 'max',
        'reshared': 'max',
        'comment_text': lambda x: ' || '.join(x.dropna()) if not x.dropna().empty else np.nan
    }
    unified_df = df.groupby('normalized_name').agg(aggregation_rules).reset_index(drop=True)

    # 6. Add profile type one-hot encoding based on the reference URL
    unified_df['is_company'] = unified_df['profile_url'].str.contains('/company/').astype(int)
    unified_df['is_individual'] = unified_df['profile_url'].str.contains('/in/').astype(int)
    
    # 7. Final Cleanup
    # Nullify the 'headline' for companies
    unified_df.loc[unified_df['is_company'] == 1, 'headline'] = np.nan
    
    # Fill any missing one-hot columns and ensure integer type
    for col in ['reacted', 'commented', 'reshared']:
        if col not in unified_df.columns: unified_df[col] = 0
        unified_df[col] = unified_df[col].fillna(0).astype(int)
    
    # Reorder columns for final output
    final_cols = [
        'name', 'headline', 'profile_url', 'is_individual', 'is_company', 
        'reacted', 'commented', 'reshared', 'comment_text'
    ]
    unified_df = unified_df[[col for col in final_cols if col in unified_df.columns]]
    
    return unified_df

# --- Execution ---
audience_final_df = clean_and_finalize_audience(reactions_raw, reshares_raw, comments_raw)

print("--- Final, Corrected Audience DataFrame ---")
print(f"Successfully consolidated into {len(audience_final_df)} unique entities.")
display(audience_final_df.head(10))
# Out:
# --- Final, Corrected Audience DataFrame ---
# Successfully consolidated into 101 unique entities.
#                           name  \
# 0             Alexander Farsan
# 1              Alexandra Colac
# 2  Alexandre Fernandes Ribeiro
# 3  Alicia Mireya Daza Castillo
# 4                Anders Norlin
# 5     Andrew Sangjun, Rhee PhD
# 6        András László Tölgyes
# 7              Anna Samuelsson
# 8              Arina Lopukhina
# 9              Arina Timofeeva
#
#                                                                                                               headline  \
# 0                                                                            Head of Climate and Environment at Klarna
# 1                                         Sustainability, Circularity, Social and Environmental Impact in Value Chains
# 2                                                         VP of Sales, Orchestration at Solidgate | Forbes 30 Under 30
# 3                                                                                                    Software Engineer
# 4               Venture Builder | Strategic Advisor | Board Executive | Investor | 💚 Impact°Nature°Climate°Tech | 💙💛🇺🇦
# 5                  Consultant | Ethnography Empirical Market Reserach; Behavioral Finance, Decarbonization | PhD | PwC
# 6  We live in a world where there is more and more information, and less and less meaning | Iratkozz fel a STALKER-re!
# 7                                                                                          Head of Impact at Milkywire
# 8                                                                Business Analytics @PayPal | MSc. Data Science @UniMi
# 9                                                                             Business Operations Specialist at Klarna
#
#                                                            profile_url  \
# 0  https://www.linkedin.com/in/ACoAAAL-E6kBmzH0Blq_dzcDp-WtSU3OSYg26gY
# 1  https://www.linkedin.com/in/ACoAAA1cp40BWBOz34A22Cgg8L0qaSXm8GTpcJY
# 2  https://www.linkedin.com/in/ACoAABGzRN8Bd8G_ELQegslYJxfvJJbz2dBH8J8
# 3  https://www.linkedin.com/in/ACoAABtWavgBCI8YAhxGSbyRrVz6_X0jnmW4xcw
# 4  https://www.linkedin.com/in/ACoAAADrI4EB6MOg-PQqxjPTaPvRqQktwAtiwPg
# 5  https://www.linkedin.com/in/ACoAACBUpIQBTN-Bhl3Y-iOH_278PKuXkibozCc
# 6  https://www.linkedin.com/in/ACoAAAO2lIsBHVf3MzMCLSkGPz7mZdjsd4KM0rI
# 7  https://www.linkedin.com/in/ACoAAAj0a_YBQhe8tUaTspBVy4peYc4CT9f8a0k
# 8  https://www.linkedin.com/in/ACoAABjIeKUBePaAMYDMYaEEICokC7XJ9xTSLZc
# 9  https://www.linkedin.com/in/ACoAACxhRwcBiBv3kmwhxpGtHeX1EqLhcpWyJ2I
#
#    is_individual  is_company  reacted  commented  reshared comment_text
# 0              1           0        1          0         1          NaN
# 1              1           0        1          0         1          NaN
# 2              1           0        1          0         1          NaN
# 3              1           0        1          0         0          NaN
# 4              1           0        1          0         0          NaN
# 5              1           0        1          0         0          NaN
# 6              1           0        1          0         1          NaN
# 7              1           0        1          0         0          NaN
# 8              1           0        1          0         0          NaN
# 9              1           0        1          0         0          NaN

# %% [markdown]
# ## Task 1 analysis

# %%
import pandas as pd
from textblob import TextBlob

def analyze_post_features(df):
    """
    Analyzes the post DataFrame to add sentiment and performance features.
    
    Args:
        df (pd.DataFrame): The cleaned DataFrame containing post data.

    Returns:
        pd.DataFrame: The DataFrame with added analysis columns.
    """
    if df.empty:
        print("Post DataFrame is empty. Cannot analyze.")
        return df

    # We are working with the first (and only) row
    post_text = df['post_text'].iloc[0]

    # --- 1.1: Sentiment Analysis ---
    blob = TextBlob(post_text)
    df['sentiment_polarity'] = blob.sentiment.polarity
    df['sentiment_subjectivity'] = blob.sentiment.subjectivity

    # Categorize sentiment based on polarity
    if blob.sentiment.polarity > 0.1:
        df['sentiment'] = 'Positive'
    elif blob.sentiment.polarity < -0.1:
        df['sentiment'] = 'Negative'
    else:
        df['sentiment'] = 'Neutral'

    # --- 1.2: Feature Creation ---
    df['text_length'] = len(post_text)
    df['hashtag_count'] = len(df['hashtags'].iloc[0])
    
    # Engagement metric for prototype (since we don't have follower count)
    df['engagement_sum'] = df['likes_count'] + df['comments_count']

    return df

# --- Execution ---
post_analyzed_df = analyze_post_features(post_df.copy()) # Use .copy() to avoid modifying the original df

# Display the results
print("--- Post Performance and Feature Analysis ---")
display(post_analyzed_df[[
    'sentiment', 'sentiment_polarity', 'likes_count', 'comments_count', 
    'engagement_sum', 'text_length', 'hashtag_count'
]].T.rename(columns={0: 'Value'}))
# Out:
# --- Post Performance and Feature Analysis ---
#                        Value
# sentiment           Positive
# sentiment_polarity  0.132487
# likes_count               98
# comments_count             7
# engagement_sum           105
# text_length             1374
# hashtag_count              0

# %%
import pandas as pd
import numpy as np

def analyze_audience_by_icp(df):
    """
    Analyzes the unified audience DataFrame to score and rank individuals
    based on a predefined Ideal Customer Profile (ICP).

    Args:
        df (pd.DataFrame): The final, cleaned, and unified audience DataFrame.

    Returns:
        A tuple containing:
        - pd.DataFrame: A ranked DataFrame of individuals with relevance scores.
        - pd.Series: A summary of the top roles found in the audience.
        - pd.Series: A summary of the top seniority levels found in the audience.
    """
    # 1. Filter for only individual profiles and drop rows with no headline
    individuals_df = df[(df['is_individual'] == 1) & (df['headline'].notna())].copy()
    if individuals_df.empty:
        print("No individuals with headlines found to analyze.")
        return pd.DataFrame(), pd.Series(dtype='int64'), pd.Series(dtype='int64')

    # 2. Define the Ideal Customer Profile (ICP) with keywords and scores
    icp_keywords = {
        # Role Keywords
        'sustainability': 3, 'climate': 3, 'esg': 3,
        'ai': 2, 'data scientist': 2, 'engineer': 1,
        'investor': 3, 'venture': 2,
        'founder': 3, 'entrepreneur': 2,
        'innovation': 2, 'tech': 1, 'consultant': 1,
        # Seniority Keywords
        'ceo': 3, 'chief': 3, 'c-level': 3,
        'head of': 2, 'vp': 2, 'director': 2, 'partner': 2,
        'lead': 1, 'manager': 1, 'senior': 1
    }
    
    role_keys = {'sustainability', 'climate', 'esg', 'ai', 'data scientist', 'engineer', 'investor', 'venture', 'founder', 'entrepreneur', 'innovation', 'tech', 'consultant'}
    seniority_keys = {'ceo', 'chief', 'c-level', 'head of', 'vp', 'director', 'partner', 'lead', 'manager', 'senior', 'founder'}

    # 3. Function to score a headline
    def score_headline(headline):
        score = 0
        matches = []
        headline_lower = headline.lower()
        for keyword, value in icp_keywords.items():
            if keyword in headline_lower:
                score += value
                matches.append(keyword)
        return score, matches

    # 4. Apply the scoring function to create new columns
    individuals_df[['relevance_score', 'matched_keywords']] = individuals_df['headline'].apply(
        lambda h: pd.Series(score_headline(h))
    )

    # 5. Rank the audience by the calculated score
    ranked_df = individuals_df.sort_values(by='relevance_score', ascending=False)
    
    # 6. Create Audience Summaries
    all_keywords = ranked_df[ranked_df['matched_keywords'].apply(lambda x: len(x) > 0)]['matched_keywords'].explode()
    
    top_roles = all_keywords[all_keywords.isin(role_keys)].value_counts()
    top_seniority = all_keywords[all_keywords.isin(seniority_keys)].value_counts()

    return ranked_df, top_roles, top_seniority


# --- Execution ---
# We use the 'audience_final_df' which has been properly de-duplicated
ranked_audience_final_df, top_roles, top_seniority = analyze_audience_by_icp(audience_final_df)


# --- Display Final Results ---
print("--- Audience Analysis & ICP Ranking (Final, Corrected Data) ---")

if not ranked_audience_final_df.empty:
    print("\nTop 10 Most Relevant Individuals in the Audience:")
    display(ranked_audience_final_df[[
        'name', 'headline', 'relevance_score', 'matched_keywords'
    ]].head(10))

    print("\n--- Audience Composition Summary ---")
    print("\nTop Roles Found:")
    display(top_roles.head(10).to_frame(name='Count'))

    print("\nTop Seniority Levels Found:")
    display(top_seniority.head(10).to_frame(name='Count'))
else:
    print("Could not generate audience analysis.")
# Out:
# --- Audience Analysis & ICP Ranking (Final, Corrected Data) ---
#
# Top 10 Most Relevant Individuals in the Audience:
#                                     name  \
# 85                            Salah Said
# 24                       Dhanesh Kothari
# 74                        Peter Githinji
# 62  Mike Alves, MSAFP, CFP®, CEPA, CRPC®
# 97                                 Vy Do
# 4                          Anders Norlin
# 51                Katarina Wangler Björk
# 50                       Jörgen Johnsson
# 37            Fredrik Andersson Guldkula
# 23                           Deqa Abukar
#
#                                                                                                                                                                                                                       headline  \
# 85                   Sustainability I ESG I Corporate Responsibility at Klarna I ex-Zalando | Social Innovation & Entrepreneurship | Design Thinking | BMI | LSP | Sustainable Fashion / Finance / E-commerce | Carbon Removal
# 24  Compassionate Capitalism | Founder of pi2Life - Funder, B2B Marketplace, Product Locator, Shopical | Ethics | Entrepreneur | Mentor | Board Advisor | Sustainability | Impact | VeganTech | FinTech | RetailTech | Digital
# 74                                                                             Climate Finance & Carbon Markets Strategist | Co-Founder, KiotaSIC | Accelerating Sustainable Innovation & Economic Opportunity in East Africa.
# 62                                                             Founder & Managing Partner | Late-Stage Pre-IPO AI & Humanoid Robotics Fund | Investing in Innovation & Future Tech | Building a Legacy for the Next Generation
# 97                                                                           Sustainability Strategy & Digital Transformation | Leveraging AI & Automation for Climate Impact | MSc Sustainability Leadership - Let's Connect!
# 4                                                                                                                       Venture Builder | Strategic Advisor | Board Executive | Investor | 💚 Impact°Nature°Climate°Tech | 💙💛🇺🇦
# 51                                                                                                    IMAGINE Leader | Climate, Sustain Tech & Policy | Sustainable Business Innovation Transformation & Finance | Ex-EY | MBA
# 50                                                                                                                                                                          Founder and CEO at Johnson Real Estate Venture INC
# 37                                                                                                                                                                            Climate tech investor @ R-evolution (Hexagon AB)
# 23                                                                                                                                                                                                  Co-founder BLING, Investor
#
#     relevance_score                                     matched_keywords
# 85               12  [sustainability, esg, ai, entrepreneur, innovation]
# 24               11    [sustainability, ai, founder, entrepreneur, tech]
# 74               10                   [climate, ai, founder, innovation]
# 62               10             [ai, founder, innovation, tech, partner]
# 97                9                  [sustainability, climate, ai, lead]
# 4                 9                   [climate, investor, venture, tech]
# 51                9                [climate, ai, innovation, tech, lead]
# 50                8                              [venture, founder, ceo]
# 37                7                            [climate, investor, tech]
# 23                6                                  [investor, founder]
# --- Audience Composition Summary ---
#
# Top Roles Found:
#                   Count
# matched_keywords
# ai                   17
# engineer             15
# tech                 10
# founder               7
# climate               7
# sustainability        5
# innovation            5
# investor              4
# consultant            4
# entrepreneur          3
# Top Seniority Levels Found:
#                   Count
# matched_keywords
# manager              19
# lead                 10
# head of              10
# senior                9
# founder               7
# partner               7
# ceo                   5
# director              3
# vp                    2
# chief                 1

# %%
# --- Save the final, analyzed DataFrames to CSV files ---

# 1. Save the post analysis summary
post_analyzed_df.to_csv('post_analysis_summary.csv', index=False)
print("Successfully saved: post_analysis_summary.csv")

# 2. Save the final, ranked audience analysis
# We select key columns for a clean final report
final_audience_columns = [
    'name', 'headline', 'relevance_score', 'matched_keywords', 
    'is_individual', 'is_company', 'reacted', 'commented', 'reshared', 
    'comment_text', 'profile_url'
]
ranked_audience_final_df[final_audience_columns].to_csv('audience_icp_ranking.csv', index=False)
print("Successfully saved: audience_icp_ranking.csv")
# Out:
# Successfully saved: post_analysis_summary.csv
# Successfully saved: audience_icp_ranking.csv
